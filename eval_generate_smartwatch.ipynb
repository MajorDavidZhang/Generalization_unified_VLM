# %%
import argparse
from email.mime import image
import torch
import os
import json
from tqdm import tqdm
import shortuuid

from llava.constants import IMAGE_TOKEN_INDEX, DEFAULT_IMAGE_TOKEN, DEFAULT_IM_START_TOKEN, DEFAULT_IM_END_TOKEN
from llava.conversation import conv_templates, SeparatorStyle
from llava.model.builder import load_pretrained_model
from llava.utils import disable_torch_init
from llava.mm_utils import tokenizer_image_token, process_images, get_model_name_from_path
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import math


def split_list(lst, n):
    """Split a list into n (roughly) equal-sized chunks"""
    chunk_size = math.ceil(len(lst) / n)  # integer division
    return [lst[i:i+chunk_size] for i in range(0, len(lst), chunk_size)]


def get_chunk(lst, n, k):
    chunks = split_list(lst, n)
    return chunks[k]


# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self,args, tokenizer, model_config):
        self.list_data_dict = json.load(open(args.data_path, "r"))
        self.tokenizer = tokenizer
        self.model_config = model_config
        self.image_folder = args.image_folder
        self.gen_processor=args.gen_processor
        self.un_processor=args.un_processor

    def __getitem__(self, index):
        sources = self.list_data_dict[index]
        qs = sources["conversations"][0]["value"]
        # if self.model_config.mm_use_im_start_end:
        #     qs = DEFAULT_IM_START_TOKEN + DEFAULT_IMAGE_TOKEN + DEFAULT_IM_END_TOKEN + '\n' + qs
        # else:
        #     qs = DEFAULT_IMAGE_TOKEN + '\n' + qs
        

        conv = conv_templates[args.conv_mode].copy()
        conv.append_message(conv.roles[0], qs)
        conv.append_message(conv.roles[1], None)
        prompt = conv.get_prompt()
        #print(prompt)
        image_file = sources["image"]
        image_tensor = Image.open(os.path.join(self.image_folder, image_file)).convert('RGB')
        if sources['task']=='generation':
            image_tensor = self.gen_processor.preprocess(image_tensor, return_tensors='pt')['pixel_values'][0]
        else:
            image_tensor = self.un_processor.preprocess(image_tensor, return_tensors='pt')['pixel_values'][0]
        input_ids = tokenizer_image_token(prompt, self.tokenizer, IMAGE_TOKEN_INDEX, return_tensors='pt')

        return input_ids, image_tensor

    def __len__(self):
        return len(self.list_data_dict)


def collate_fn(batch):
    input_ids, image_tensors = zip(*batch)
    input_ids = torch.stack(input_ids, dim=0)
    image_tensors = torch.stack(image_tensors, dim=0)
    return input_ids, image_tensors


# DataLoader
def create_data_loader(args, tokenizer, model_config, batch_size=1, num_workers=4):
    assert batch_size == 1, "batch_size must be 1"
    dataset = CustomDataset(args, tokenizer, model_config)
    data_loader = DataLoader(dataset, batch_size=batch_size, num_workers=num_workers, shuffle=False, collate_fn=collate_fn)
    return data_loader

def generate_image(input_ids,model,num_image_tokens):
    output_img=[]
    inputs_embeds=model.get_model().embed_tokens(input_ids) #1, seq_le, 4096
    with torch.inference_mode():
        for i in range(num_image_tokens):
            outputs = model.model(
                input_ids=None,
                attention_mask=None,
                position_ids=None,
                past_key_values=None,
                inputs_embeds=inputs_embeds,
            )
            hidden_states = outputs[0]
            img = model.get_model().mm_projector_head(hidden_states[:,-1,:])
            output_img.append(img)
            if model.get_model().mm_projector_gen is not None:
                new_embed=model.get_model().mm_projector_gen(img)
            else:
                new_embed=model.get_model().mm_projector_un(img)
            new_embed=new_embed.unsqueeze(1).to(inputs_embeds.device)
            inputs_embeds=torch.cat([inputs_embeds,new_embed],dim=1)
            
    return output_img
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       6 from tqdm import tqdm
#       7 import shortuuid
# ----> 9 from llava.constants import IMAGE_TOKEN_INDEX, DEFAULT_IMAGE_TOKEN, DEFAULT_IM_START_TOKEN, DEFAULT_IM_END_TOKEN
#      10 from llava.conversation import conv_templates, SeparatorStyle
#      11 from llava.model.builder import load_pretrained_model
#
# File /public_data/jihai/understanding/llava/__init__.py:1
# ----> 1 from .model import LlavaLlamaForCausalLM,LlavaLlamaForCausalLM_ImgGen
#
# ImportError: cannot import name 'LlavaLlamaForCausalLM' from 'llava.model' (/public_data/jihai/understanding/llava/model/__init__.py)

# %%
import torch

# 加载 .bin 文件
file_path = "/datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-31/non_lora_trainables.bin"
state_dict = torch.load(file_path, map_location='cpu')  # map_location='cpu' 确保在 CPU 上加载

# 加载 .bin 文件
file_path2 = "/datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-62/non_lora_trainables.bin"
state_dict2 = torch.load(file_path2, map_location='cpu')  # map_location='cpu' 确保在 CPU 上加载

# 查看所有参数的名字
for name, param in state_dict.items():
    check=torch.equal(param,state_dict2[name])
    print(f"Parameter name: {name}, check: {check}")
# Out:
# Parameter name: base_model.model.model.mm_projector_un.0.weight, check: False
# Parameter name: base_model.model.model.mm_projector_un.0.bias, check: False
# Parameter name: base_model.model.model.mm_projector_un.2.weight, check: False
# Parameter name: base_model.model.model.mm_projector_un.2.bias, check: False
# Parameter name: base_model.model.model.mm_projector_head.weight, check: False
# Parameter name: base_model.model.model.mm_projector_head.bias, check: False

# %%
#load trained model
device='cuda:1'
ckp_list=[i*391 for i in range(1,6)]
model_name='llava-v1.5-7b-segment_digit-lora'
model_list=[f'/datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/{model_name}/checkpoint-{i}' for i in ckp_list]
for k in range(len(model_list)):
    args = type('Args', (), {
        "model_path": model_list[k],
        "model_base": '/datadrive_a/tmp/vicuna-7b-v1.5/vicuna-7b-v1.5',
        "data_path": '/datadrive_a/jihai/data/multimodalout/smart_watch_eval.json',
        "image_folder": '/datadrive_a/jihai/data/multimodalout/smart_watch_image',
        "answers_file": f"./answer/answer-{model_name}-{k}.jsonl",
        "conv_mode": "llava_v1",
        "num_chunks": 1,
        "chunk_idx": 0,
        "temperature": 0,
        "top_p": None,
        "num_beams": 1,
        "max_new_tokens": 128
    })()
    print(args.model_path)
    disable_torch_init()
    model_path = os.path.expanduser(args.model_path)
    print(model_path)
    model_type = get_model_name_from_path(model_path)
    tokenizer, model, image_processor,image_processor_gen, context_len = load_pretrained_model(model_path, args.model_base, model_name,device=device)
    args.gen_processor=image_processor_gen
    args.un_processor=image_processor


    answers_file = args.answers_file
    os.makedirs(os.path.dirname(answers_file), exist_ok=True)
    ans_file = open(answers_file, "w")
    if 'plain' in model_type and 'finetune' not in model_type.lower() and 'mmtag' not in args.conv_mode:
        args.conv_mode = args.conv_mode + '_mmtag'
        print(f'It seems that this is a plain model, but it is not using a mmtag prompt, auto switching to {args.conv_mode}.')

    data_loader = create_data_loader(args, tokenizer, model.config)
    list_data_dict = json.load(open(args.data_path, "r"))


    count=0
    for (input_ids, image_tensor), line in tqdm(zip(data_loader, list_data_dict), total=len(list_data_dict)):
        count+=1
        if count==500: break
    
        cur_prompt = line["conversations"][0]["value"]
        groun_truth=line["conversations"][1]["value"]
        groun_truth_img_tensor=line["image"]
        input_ids = input_ids.to(device=device, non_blocking=True)
        image_tensor=image_tensor.to(dtype=torch.float16, device=device, non_blocking=True)
        with torch.inference_mode():
            outputs = model.generate(
                input_ids,
                images=image_tensor,
                do_sample=True if args.temperature > 0 else False,
                temperature=args.temperature,
                top_p=args.top_p,
                num_beams=args.num_beams,
                max_new_tokens=args.max_new_tokens,
                use_cache=True)
        output_ids=outputs['generated_tokens']
        outputs = tokenizer.batch_decode(output_ids, skip_special_tokens=False)[0].strip()
        #print(outputs)

        img_indicator = torch.tensor([529,  3027, 29958])
        id_seq = output_ids[0].cpu()

        # 子序列长度
        sub_seq_len = len(img_indicator)

        # 滑动窗口查找子序列
        start_idx = -1
        for i in range(id_seq.size(0) - sub_seq_len + 1):
            if torch.equal(id_seq[i:i + sub_seq_len], img_indicator):
                start_idx = i
                break
        img=None
        if start_idx != -1:
            output_ids=output_ids[:,1:start_idx+3]
            input_ids=torch.cat((input_ids, output_ids), dim=1)
            img=generate_image(input_ids,model)
            img=torch.stack(img,dim=0).squeeze().cpu().tolist()
        ans_file.write(json.dumps({"prompt": cur_prompt,
                                    "groun_truth": groun_truth,
                                    "answer": outputs,
                                    "groun_truth_img_tensor": groun_truth_img_tensor,
                                    "output_img_tensor": img,
                                    "model_id": model_name,
                                    "metadata": {}}) + "\n")
        #outputs = tokenizer.batch_decode(input_ids, skip_special_tokens=False)[0].strip()
    
    print(ans_file)
    ans_file.close()
# Out:
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-62
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-62
# Loading LLaVA from base model...
# /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]/datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.56s/it]
# Some weights of LlavaLlamaForCausalLM_ImgGen were not initialized from the model checkpoint at /datadrive_a/tmp/vicuna-7b-v1.5/vicuna-7b-v1.5 and are newly initialized: ['model.mm_projector_head.bias', 'model.mm_projector_head.weight', 'model.mm_projector_un.0.bias', 'model.mm_projector_un.0.weight', 'model.mm_projector_un.2.bias', 'model.mm_projector_un.2.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading additional LLaVA weights...
# Loading LoRA weights...
# Merging LoRA weights...
# Model is loaded...
#   0%|          | 0/800 [00:00<?, ?it/s]/datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:397: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `None` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  62%|██████▏   | 499/800 [10:58<06:37,  1.32s/it]
# <_io.TextIOWrapper name='./answer/answer-llava-v1.5-7b-sw-lora-0.jsonl' mode='w' encoding='UTF-8'>
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-124
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-124
# Loading LLaVA from base model...
# Loading checkpoint shards: 100%|██████████| 2/2 [00:08<00:00,  4.47s/it]
# Some weights of LlavaLlamaForCausalLM_ImgGen were not initialized from the model checkpoint at /datadrive_a/tmp/vicuna-7b-v1.5/vicuna-7b-v1.5 and are newly initialized: ['model.mm_projector_head.bias', 'model.mm_projector_head.weight', 'model.mm_projector_un.0.bias', 'model.mm_projector_un.0.weight', 'model.mm_projector_un.2.bias', 'model.mm_projector_un.2.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading additional LLaVA weights...
# Loading LoRA weights...
# Merging LoRA weights...
# Model is loaded...
#  62%|██████▏   | 499/800 [09:22<05:39,  1.13s/it]
# <_io.TextIOWrapper name='./answer/answer-llava-v1.5-7b-sw-lora-1.jsonl' mode='w' encoding='UTF-8'>
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-186
# /datadrive_a/jihai/LLaVA/scripts/v1_5/checkpoints/llava-v1.5-7b-sw-lora/checkpoint-186
# Loading LLaVA from base model...
# Loading checkpoint shards: 100%|██████████| 2/2 [00:08<00:00,  4.17s/it]
# Some weights of LlavaLlamaForCausalLM_ImgGen were not initialized from the model checkpoint at /datadrive_a/tmp/vicuna-7b-v1.5/vicuna-7b-v1.5 and are newly initialized: ['model.mm_projector_head.bias', 'model.mm_projector_head.weight', 'model.mm_projector_un.0.bias', 'model.mm_projector_un.0.weight', 'model.mm_projector_un.2.bias', 'model.mm_projector_un.2.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading additional LLaVA weights...
# Loading LoRA weights...
# Merging LoRA weights...
# Model is loaded...
#   1%|          | 6/800 [00:05<12:46,  1.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 53
#      51 image_tensor=image_tensor.to(dtype=torch.float16, device=device, non_blocking=True)
#      52 with torch.inference_mode():
# ---> 53     outputs = model.generate(
#      54         input_ids,
#      55         images=image_tensor,
#      56         do_sample=True if args.temperature > 0 else False,
#      57         temperature=args.temperature,
#      58         top_p=args.top_p,
#      59         num_beams=args.num_beams,
#      60         max_new_tokens=args.max_new_tokens,
#      61         use_cache=True)
#      62 output_ids=outputs['generated_tokens']
#      63 outputs = tokenizer.batch_decode(output_ids, skip_special_tokens=False)[0].strip()
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /datadrive_a/jihai/LLaVA/llava/model/language_model/llava_llama.py:259, in LlavaLlamaForCausalLM_ImgGen.generate(self, inputs, images, image_sizes, img_token_start, input_img_features, **kwargs)
#     257 kwargs['output_hidden_states'] = True
#     258 #print(inputs_embeds)
# --> 259 outputs=super().generate(
#     260     position_ids=position_ids,
#     261     attention_mask=attention_mask,
#     262     inputs_embeds=inputs_embeds,
#     263     return_dict_in_generate=True,
#     264     **kwargs
#     265 )
#     266 #print(f"outputs_keys: {outputs.keys()}")
#     267 #print(f"outputs: {outputs}")
#     268 generated_tokens=outputs['sequences']
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/generation/utils.py:1479, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1462     return self.assisted_decoding(
#    1463         input_ids,
#    1464         candidate_generator=candidate_generator,
#    (...)
#    1475         **model_kwargs,
#    1476     )
#    1477 if generation_mode == GenerationMode.GREEDY_SEARCH:
#    1478     # 11. run greedy search
# -> 1479     return self.greedy_search(
#    1480         input_ids,
#    1481         logits_processor=prepared_logits_processor,
#    1482         stopping_criteria=prepared_stopping_criteria,
#    1483         pad_token_id=generation_config.pad_token_id,
#    1484         eos_token_id=generation_config.eos_token_id,
#    1485         output_scores=generation_config.output_scores,
#    1486         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1487         synced_gpus=synced_gpus,
#    1488         streamer=streamer,
#    1489         **model_kwargs,
#    1490     )
#    1492 elif generation_mode == GenerationMode.CONTRASTIVE_SEARCH:
#    1493     if not model_kwargs["use_cache"]:
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/generation/utils.py:2340, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2337 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2339 # forward pass to get next token
# -> 2340 outputs = self(
#    2341     **model_inputs,
#    2342     return_dict=True,
#    2343     output_attentions=output_attentions,
#    2344     output_hidden_states=output_hidden_states,
#    2345 )
#    2347 if synced_gpus and this_peer_finished:
#    2348     continue  # don't waste resources running the code we don't need
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /datadrive_a/jihai/LLaVA/llava/model/language_model/llava_llama.py:111, in LlavaLlamaForCausalLM_ImgGen.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, images, image_sizes, return_dict, cache_position, num_logits_to_keep, img_token_start, **loss_kwargs)
#     108 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     110 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 111 outputs = self.model(
#     112     input_ids=input_ids,
#     113     attention_mask=attention_mask,
#     114     position_ids=position_ids,
#     115     past_key_values=past_key_values,
#     116     inputs_embeds=inputs_embeds,
#     117     use_cache=use_cache,
#     118     output_attentions=output_attentions,
#     119     output_hidden_states=output_hidden_states,
#     120     return_dict=return_dict,
#     121 )
#     123 hidden_states = outputs[0]
#     124 if self.config.pretraining_tp > 1:
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:1070, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1060     layer_outputs = self._gradient_checkpointing_func(
#    1061         decoder_layer.__call__,
#    1062         hidden_states,
#    (...)
#    1067         use_cache,
#    1068     )
#    1069 else:
# -> 1070     layer_outputs = decoder_layer(
#    1071         hidden_states,
#    1072         attention_mask=attention_mask,
#    1073         position_ids=position_ids,
#    1074         past_key_value=past_key_values,
#    1075         output_attentions=output_attentions,
#    1076         use_cache=use_cache,
#    1077     )
#    1079 hidden_states = layer_outputs[0]
#    1081 if use_cache:
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:795, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     789     warnings.warn(
#     790         "Passing `padding_mask` is deprecated and will be removed in v4.37. Please make sure use `attention_mask` instead.`"
#     791     )
#     793 residual = hidden_states
# --> 795 hidden_states = self.input_layernorm(hidden_states)
#     797 # Self Attention
#     798 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     799     hidden_states=hidden_states,
#     800     attention_mask=attention_mask,
#    (...)
#     805     **kwargs,
#     806 )
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /datadrive_a/jihai/miniconda3/envs/llava/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:116, in LlamaRMSNorm.forward(self, hidden_states)
#     114 hidden_states = hidden_states.to(torch.float32)
#     115 variance = hidden_states.pow(2).mean(-1, keepdim=True)
# --> 116 hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     117 return self.weight * hidden_states.to(input_dtype)
#
# KeyboardInterrupt:

# %%
for name, param in model.named_parameters():
    print(f"Parameter: {name}, Device: {param.device}")
# Out:
# Parameter: model.embed_tokens.weight, Device: cuda:1
# Parameter: model.layers.0.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.0.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.0.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.0.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.0.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.0.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.0.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.0.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.0.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.1.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.1.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.1.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.1.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.1.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.1.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.1.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.1.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.1.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.2.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.2.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.2.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.2.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.2.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.2.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.2.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.2.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.2.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.3.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.3.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.3.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.3.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.3.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.3.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.3.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.3.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.3.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.4.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.4.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.4.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.4.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.4.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.4.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.4.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.4.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.4.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.5.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.5.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.5.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.5.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.5.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.5.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.5.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.5.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.5.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.6.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.6.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.6.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.6.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.6.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.6.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.6.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.6.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.6.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.7.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.7.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.7.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.7.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.7.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.7.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.7.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.7.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.7.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.8.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.8.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.8.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.8.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.8.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.8.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.8.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.8.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.8.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.9.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.9.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.9.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.9.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.9.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.9.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.9.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.9.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.9.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.10.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.10.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.10.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.10.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.10.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.10.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.10.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.10.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.10.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.11.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.11.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.11.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.11.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.11.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.11.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.11.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.11.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.11.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.12.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.12.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.12.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.12.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.12.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.12.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.12.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.12.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.12.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.13.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.13.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.13.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.13.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.13.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.13.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.13.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.13.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.13.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.14.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.14.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.14.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.14.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.14.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.14.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.14.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.14.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.14.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.15.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.15.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.15.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.15.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.15.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.15.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.15.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.15.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.15.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.16.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.16.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.16.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.16.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.16.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.16.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.16.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.16.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.16.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.17.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.17.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.17.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.17.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.17.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.17.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.17.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.17.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.17.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.18.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.18.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.18.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.18.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.18.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.18.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.18.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.18.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.18.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.19.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.19.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.19.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.19.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.19.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.19.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.19.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.19.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.19.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.20.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.20.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.20.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.20.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.20.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.20.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.20.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.20.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.20.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.21.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.21.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.21.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.21.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.21.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.21.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.21.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.21.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.21.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.22.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.22.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.22.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.22.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.22.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.22.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.22.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.22.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.22.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.23.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.23.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.23.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.23.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.23.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.23.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.23.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.23.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.23.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.24.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.24.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.24.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.24.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.24.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.24.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.24.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.24.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.24.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.25.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.25.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.25.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.25.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.25.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.25.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.25.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.25.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.25.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.26.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.26.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.26.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.26.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.26.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.26.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.26.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.26.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.26.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.27.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.27.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.27.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.27.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.27.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.27.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.27.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.27.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.27.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.28.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.28.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.28.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.28.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.28.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.28.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.28.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.28.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.28.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.29.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.29.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.29.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.29.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.29.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.29.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.29.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.29.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.29.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.30.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.30.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.30.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.30.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.30.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.30.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.30.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.30.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.30.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.layers.31.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.layers.31.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.layers.31.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.layers.31.self_attn.o_proj.weight, Device: cuda:1
# Parameter: model.layers.31.mlp.gate_proj.weight, Device: cuda:1
# Parameter: model.layers.31.mlp.up_proj.weight, Device: cuda:1
# Parameter: model.layers.31.mlp.down_proj.weight, Device: cuda:1
# Parameter: model.layers.31.input_layernorm.weight, Device: cuda:1
# Parameter: model.layers.31.post_attention_layernorm.weight, Device: cuda:1
# Parameter: model.norm.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.embeddings.patch_embedding.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.embeddings.patch_embedding.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.embeddings.position_embedding.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.2.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.3.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.4.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.5.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.6.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.7.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.8.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.9.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.layer_norm1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.layer_norm1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.mlp.fc2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.layer_norm2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.encoder.layers.11.layer_norm2.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.post_layernorm.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.post_layernorm.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.probe, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.attention.in_proj_weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.attention.in_proj_bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.attention.out_proj.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.attention.out_proj.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.layernorm.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.layernorm.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.mlp.fc1.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.mlp.fc1.bias, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.mlp.fc2.weight, Device: cuda:1
# Parameter: model.vision_tower.vision_tower.vision_model.head.mlp.fc2.bias, Device: cuda:1
# Parameter: model.mm_projector_un.0.weight, Device: cuda:1
# Parameter: model.mm_projector_un.0.bias, Device: cuda:1
# Parameter: model.mm_projector_un.2.weight, Device: cuda:1
# Parameter: model.mm_projector_un.2.bias, Device: cuda:1
# Parameter: model.mm_projector_head.weight, Device: cuda:1
# Parameter: model.mm_projector_head.bias, Device: cuda:1
# Parameter: lm_head.weight, Device: cuda:1
